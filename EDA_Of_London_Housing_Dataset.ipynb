# %% [markdown]
# <a href="https://colab.research.google.com/github/seunseitan/-EDA-Of-London-Housing-Dataset/blob/main/EDA_Of_London_Housing_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Analyzing "London Housing Dataset" with Python**
#
# **London Housing Dataset**
#
# **This housing dataset is primarily concerned around the housing market of London. It contains a lot of additional relevant data.**
#
# - Monthly average house prices
#
# - Yearly number of houses sold
#
# - Monthly number of crimes committed
#
#
# The data availabe here is from year 1995 to 2019 of each different area
# The data is availabe as a CSV file, downloaded from Kaggle

# %% [markdown]
# The data availabe here is from year 1995 to 2019 of each different area
#
# The data is availabe as a CSV file, downloaded from Kaggle

# %%
import pandas as pd

# %%
data = pd.read_csv(r"/content/drive/MyDrive/Python Folder/London Housing Data.csv")
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **(A) Convert the Datatype of "Date" column to Date-Time format**

# %%
data.dtypes       #BEFORE CONVERSION, THE DATETYPE OF DATE CAN BE SEEN AS OBJECT
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data.date=pd.to_datetime(data.date)      #CONVERSION

# %%
data.dtypes      #AFTER CONVERSION, THE DATATYPE OF DATE CAN BE SEEN AS DATE TIME
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# **(B.1) Add a new column "Year" in the dataframe, which contains years only**

# %%
data["year"]=data.date.dt.year

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %% [markdown]
# **(B.2) Add a new column "month" in the dataframe, which contains month only**

# %%
data.insert(1, "month", data.date.dt.month)

# %%
data
# Out:
#             date  month            area  average_price       code  \
# 0     1995-01-01      1  city of london          91449  E09000001
# 1     1995-02-01      2  city of london          82203  E09000001
# 2     1995-03-01      3  city of london          79121  E09000001
# 3     1995-04-01      4  city of london          77101  E09000001
# 4     1995-05-01      5  city of london          84409  E09000001
# ...          ...    ...             ...            ...        ...
# 13544 2019-09-01      9         england         249942  E92000001
# 13545 2019-10-01     10         england         249376  E92000001
# 13546 2019-11-01     11         england         248515  E92000001
# 13547 2019-12-01     12         england         250410  E92000001
# 13548 2020-01-01      1         england         247355  E92000001
#
#        houses_sold  no_of_crimes  year
# 0             17.0           NaN  1995
# 1              7.0           NaN  1995
# 2             14.0           NaN  1995
# ...

# %% [markdown]
# **(C) Remove the columns "year" and "month" from the dataframe**

# %%
data.drop(["month","year"],axis=1,inplace=True)

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# **(D) Show all the records where "no_of_crimes" is 0 and how many of such records are there?**

# %%
data[data.no_of_crimes==0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
len(data[data.no_of_crimes==0])    #There are 104 records/rows where no_of_crimes equal zero
# Out:
# 104

# %% [markdown]
# **(D) What is the "average_price" per year in England?**

# %%
data["year"]=data.date.dt.year

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
data.groupby("year").average_price.mean()
# Out:
# year
# 1995     75880.235185
# 1996     78875.274908
# 1997     89618.350000
# 1998    101747.073801
# 1999    114256.172222
# 2000    139979.442593
# 2001    156932.355556
# 2002    182190.731481
# 2003    205099.553704
# 2004    224604.720370
# 2005    233314.512963
# 2006    249303.109259
# 2007    285944.279630
# 2008    287478.972222
# 2009    259296.896296
# 2010    287559.164815
# 2011    294819.138889
# 2012    309409.501852
# 2013    334589.564815
# 2014    388208.392593
# 2015    421356.100000
# 2016    454884.461111
# 2017    469978.938889
# 2018    467240.674074
# 2019    460056.659259
# 2020    463329.977778
# Name: average_price, dtype: float64

# %% [markdown]
# As the years go by, it appears that the average house price in England is rising.

# %% [markdown]
# **(E) What is the maximum and minimum number of crimes recorded per area?**

# %%
data.groupby("area").no_of_crimes.max().sort_values(ascending=False) #MAXINUM NUMBER OF CRIMES RECORDED PER AREA
# Out:
# area
# westminster               7461.0
# lambeth                   4701.0
# camden                    4558.0
# southwark                 3821.0
# newham                    3668.0
# hackney                   3466.0
# ealing                    3401.0
# islington                 3384.0
# tower hamlets             3316.0
# croydon                   3263.0
# haringey                  3199.0
# wandsworth                3051.0
# waltham forest            2941.0
# brent                     2937.0
# barnet                    2893.0
# greenwich                 2853.0
# hillingdon                2819.0
# hounslow                  2817.0
# lewisham                  2813.0
# enfield                   2798.0
# kensington and chelsea    2778.0
# hammersmith and fulham    2645.0
# bromley                   2637.0
# redbridge                 2560.0
# barking and dagenham      2049.0
# havering                  1956.0
# bexley                    1914.0
# harrow                    1763.0
# ...

# %%
data.groupby("area").no_of_crimes.min().sort_values(ascending=True)  #MINIMUM NUMBER OF CRIMES PER AREA
# Out:
# area
# city of london               0.0
# kingston upon thames       692.0
# richmond upon thames       700.0
# sutton                     787.0
# merton                     819.0
# bexley                     860.0
# harrow                     937.0
# havering                  1130.0
# barking and dagenham      1217.0
# hammersmith and fulham    1323.0
# kensington and chelsea    1347.0
# bromley                   1441.0
# hillingdon                1445.0
# redbridge                 1487.0
# greenwich                 1513.0
# hounslow                  1529.0
# haringey                  1536.0
# waltham forest            1575.0
# wandsworth                1582.0
# enfield                   1635.0
# tower hamlets             1646.0
# lewisham                  1675.0
# barnet                    1703.0
# brent                     1850.0
# hackney                   1870.0
# ealing                    1871.0
# islington                 1871.0
# croydon                   2031.0
# ...

# %% [markdown]
# **(F) Show relationships between variables**

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
data_corr=data.corr()
sns.heatmap(data_corr,cmap="BrBG", annot=True)
data_corr
# Out:
# <ipython-input-25-7d3d298d2e41>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_corr=data.corr()
#                average_price  houses_sold  no_of_crimes      year
# average_price       1.000000    -0.168256      0.113835  0.664045
# houses_sold        -0.168256     1.000000      0.246839 -0.034938
# no_of_crimes        0.113835     0.246839      1.000000 -0.115136
# year                0.664045    -0.034938     -0.115136  1.000000

# %%
#correlation between year and price
fig,ax = plt.subplots(figsize= (10 , 6))
ax.scatter(data["year"], data["average_price"])
ax.set_xlabel('year')
ax.set_ylabel('average_price')
plt.show()
